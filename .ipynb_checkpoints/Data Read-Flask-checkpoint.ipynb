# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import urllib
import matplotlib.dates as mdates

# %%
# File to Load (Remember to Change These)
file_to_load = "Resources/Zillow San Diego Value - Sheet1.csv"

# Read Purchasing File and store into Pandas data frame
zillow_price_df = pd.read_csv(file_to_load)

# %%
zillow_price_df.head()
# Out:
#    RegionID   RegionName State               Metro        CountyName  \
# 0     54296    San Diego    CA  San Diego-Carlsbad  San Diego County
# 1     51405  Chula Vista    CA  San Diego-Carlsbad  San Diego County
# 2      6285    Oceanside    CA  San Diego-Carlsbad  San Diego County
# 3     11337    Escondido    CA  San Diego-Carlsbad  San Diego County
# 4     38333     El Cajon    CA  San Diego-Carlsbad  San Diego County
#
#    SizeRank   2003-10   2003-11   2003-12   2004-01  ...  2019-05  2019-06  \
# 0         9  457335.0  463578.0  464726.0  465221.0  ...   639539   641532
# 1        96  386620.0  392796.0  397429.0  403849.0  ...   535202   537098
# 2       135  378001.0  384125.0  388660.0  395218.0  ...   536552   538453
# 3       166  394985.0  400985.0  405567.0  411689.0  ...   526525   528065
# 4       185  403971.0  410095.0  414259.0  420473.0  ...   515014   516787
#
#    2019-07  2019-08  2019-09  2019-10  2019-11  2019-12  2020-01  2020-02
# ...

# %%
zillow_price_df.dropna()
# Out:
#     RegionID        RegionName State               Metro        CountyName  \
# 0      54296         San Diego    CA  San Diego-Carlsbad  San Diego County
# 1      51405       Chula Vista    CA  San Diego-Carlsbad  San Diego County
# 2       6285         Oceanside    CA  San Diego-Carlsbad  San Diego County
# 3      11337         Escondido    CA  San Diego-Carlsbad  San Diego County
# 4      38333          El Cajon    CA  San Diego-Carlsbad  San Diego County
# 5      41517             Vista    CA  San Diego-Carlsbad  San Diego County
# 6       3975          Carlsbad    CA  San Diego-Carlsbad  San Diego County
# 7      40737        San Marcos    CA  San Diego-Carlsbad  San Diego County
# 8      41025     Spring Valley    CA  San Diego-Carlsbad  San Diego County
# 9      46089           La Mesa    CA  San Diego-Carlsbad  San Diego County
# 10     45164         Encinitas    CA  San Diego-Carlsbad  San Diego County
# ...

# %%
zillow_price_df["CityState"]= zillow_price_df["RegionName"]+ ", " + zillow_price_df["State"]

zillow_price_df.head()
# Out:
#    RegionID   RegionName State               Metro        CountyName  \
# 0     54296    San Diego    CA  San Diego-Carlsbad  San Diego County
# 1     51405  Chula Vista    CA  San Diego-Carlsbad  San Diego County
# 2      6285    Oceanside    CA  San Diego-Carlsbad  San Diego County
# 3     11337    Escondido    CA  San Diego-Carlsbad  San Diego County
# 4     38333     El Cajon    CA  San Diego-Carlsbad  San Diego County
#
#    SizeRank   2003-10   2003-11   2003-12   2004-01  ...  2019-06  2019-07  \
# 0         9  457335.0  463578.0  464726.0  465221.0  ...   641532   643626
# 1        96  386620.0  392796.0  397429.0  403849.0  ...   537098   539047
# 2       135  378001.0  384125.0  388660.0  395218.0  ...   538453   539992
# 3       166  394985.0  400985.0  405567.0  411689.0  ...   528065   529292
# 4       185  403971.0  410095.0  414259.0  420473.0  ...   516787   518815
#
#    2019-08  2019-09  2019-10  2019-11  2019-12  2020-01  2020-02  \
# ...

# %%
zillow_price_df=zillow_price_df.drop(columns=["RegionID","RegionName","State", "Metro","CountyName", "2003-10","2003-11","2003-12"])

# %%
zillow_price_df= zillow_price_df.set_index("CityState")
zillow_price_df
# Out:
#                       SizeRank    2003-10    2003-11    2003-12    2004-01  \
# CityState
# San Diego, CA                9   457335.0   463578.0   464726.0   465221.0
# Chula Vista, CA             96   386620.0   392796.0   397429.0   403849.0
# Oceanside, CA              135   378001.0   384125.0   388660.0   395218.0
# Escondido, CA              166   394985.0   400985.0   405567.0   411689.0
